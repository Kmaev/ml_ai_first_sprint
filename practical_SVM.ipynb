# %%
import csv

import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# %%
train_df = pd.read_csv("E:/dev/ml_course_rv/ml_course_homework/train.csv")

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
train_df.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %%
train_df.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
train_df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
train_df["Activity"].value_counts()
# Out:
# Activity
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: count, dtype: int64

# %%
class_names = {
    "LAYING":0,
    "STANDING":1,
    "WALKING":2,
    "SITTING":3,
    "WALKING_UPSTAIRS":4,
    "WALKING_DOWNSTAIRS":5
}

# %%
X = train_df.drop("Activity", axis=1)
y = train_df["Activity"]

# %%
y = train_df["Activity"].map(class_names)

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7347    4
# 7348    4
# 7349    4
# 7350    4
# 7351    4
# Name: Activity, Length: 7352, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
svm_model = SVC() #By default, it will use the RBF kernel, so we don't need to pass any parameters
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_model.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("_____________")
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.9354180829367778
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       275
#            1       0.84      0.88      0.86       262
#            2       0.97      0.99      0.98       226
#            3       0.88      0.83      0.85       270
#            4       0.97      0.96      0.97       225
#            5       0.98      0.97      0.97       213
#
#     accuracy                           0.94      1471
#    macro avg       0.94      0.94      0.94      1471
# weighted avg       0.94      0.94      0.94      1471
#
# _____________
# [[275   0   0   0   0   0]
#  [  0 231   0  31   0   0]
#  [  0   0 224   0   2   0]
#  [  4  43   0 223   0   0]
#  [  0   0   4   0 217   4]
#  [  0   0   2   0   5 206]]

# %% [markdown]
# GRID SEARCH #Performed to find the best values for this particular set of data

# %%
param_grid = {"C":[0.1, 1, 10, 100],
              "gamma": [1,0.1,0.01,0.001]}

# %%
grid_model = GridSearchCV(SVC(), param_grid, verbose=3)
grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.192 total time=  13.4s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.192 total time=  13.3s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.192 total time=  13.3s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.193 total time=  13.3s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.193 total time=  13.3s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.781 total time=  11.2s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.786 total time=  11.2s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.767 total time=  11.2s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.776 total time=  11.2s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.790 total time=  11.2s
# [CV 1/5] END .................C=0.1, gamma=0.01;, score=0.904 total time=   4.9s
# ...

# %%
grid_model.best_score_
# Out:
# 0.9918378906362886

# %%
grid_model.best_params_
# Out:
# {'C': 100, 'gamma': 0.01}

# %%
grid_model.best_estimator_
# Out:
# SVC(C=100, gamma=0.01)

# %%
grid_preds = grid_model.predict(X_test)

# %%
print(accuracy_score(y_test, grid_preds))
print(classification_report(y_test,grid_preds))
print("_____________")
print(confusion_matrix(y_test, grid_preds))
# Out:
# 0.990482664853841
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       275
#            1       0.98      0.97      0.98       262
#            2       1.00      1.00      1.00       226
#            3       0.97      0.98      0.98       270
#            4       1.00      1.00      1.00       225
#            5       1.00      1.00      1.00       213
#
#     accuracy                           0.99      1471
#    macro avg       0.99      0.99      0.99      1471
# weighted avg       0.99      0.99      0.99      1471
#
# _____________
# [[275   0   0   0   0   0]
#  [  0 254   0   8   0   0]
#  [  0   0 225   0   1   0]
#  [  0   5   0 265   0   0]
#  [  0   0   0   0 225   0]
#  [  0   0   0   0   0 213]]

# %%
import pickle

# %%
with open("grid_model.pkl", "wb") as file:
    pickle.dump(grid_model, file)

# %% [markdown]
# INFERENCE

# %%
test_df = train_df = pd.read_csv("E:/dev/ml_course_rv/ml_course_homework/test.csv")

# %%
y_test_inference= test_df.drop("Activity", axis=1)

# %%
pred = grid_model.predict(y_test_inference)

# %%
print(y_test_inference.iloc[0])
# Out:
# tBodyAcc-mean()-X                       0.257178
# tBodyAcc-mean()-Y                      -0.023285
# tBodyAcc-mean()-Z                      -0.014654
# tBodyAcc-std()-X                       -0.938404
# tBodyAcc-std()-Y                       -0.920091
#                                           ...
# angle(tBodyGyroJerkMean,gravityMean)    0.271151
# angle(X,gravityMean)                   -0.720009
# angle(Y,gravityMean)                    0.276801
# angle(Z,gravityMean)                   -0.057978
# subject                                 2.000000
# Name: 0, Length: 562, dtype: float64

# %%
pred[0]
# Out:
# 1

# %%
test_df["Activity"].iloc[0]
# Out:
# 'STANDING'
